# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
chunks = [1,2,3,5,7,10,15]
table = []
for i in chunks:
    table.append(np.load(f'results/chunk_size_{i}/biased_0.npy'))
    table.append(np.load(f'results/chunk_size_{i}/random_0.npy'))
    
pd.DataFrame(np.stack(table),
             columns= ["mask_type", "chunk_size", "mape_loss",
                       'hole_l1_output', 
                       'hole_mse_output', 
                       'ssim_output_5', 
                       'psnr_output', 
                       'hole_l1_output', 
                       'hole_mse_output', 
                       'ssim_output_5', 
                       'psnr_output'])
# Out:
#    mask_type chunk_size mape_loss hole_l1_output     hole_mse_output  \
# 0     biased          1         0      1.4063845   58.33912912290023
# 1     random          1         0      1.4527684   62.00435748993801
# 2     biased          2         0      1.3327235   51.44780293342823
# 3     random          2         0      1.3987741   55.25989597929957
# 4     biased          3         0      1.2041622  39.626280932035705
# 5     random          3         0      1.2422416    42.4509863670881
# 6     biased          5         0       1.109324  28.763509418280886
# 7     random          5         0      1.1789232   32.24540702126182
# 8     biased          7         0      1.1060216  28.459836996661398
# 9     random          7         0      1.1639057   31.33438861511203
# 10    biased         10         0      1.1557977   37.14118489701425
# 11    random         10         0      1.2177352   39.96582260529835
# 12    biased         15         0      1.1934013  37.953484918446506
# ...
